# %% [markdown]
# # Lending Club Loan Data
#
# ## Dataset: accepted_2007_to_2018.csv
#
# ### Objetivo
#
# Analizar la estructura, calidad y relaciones del dataset para comprender su papel dentro de la arquitectura Lakehouse y del modelo dimensional.
#
# ---
#
# ### Contexto del negocio
#
# Lending Club fue una plataforma de préstamos peer-to-peer (P2P) que conectaba inversionistas con solicitantes de crédito a través de un mercado digital.
#
# El dataset Accepted Loans contiene información histórica de préstamos aprobados entre 2007 y 2018, incluyendo características demográficas y financieras de los prestatarios, condiciones del préstamo, tasas de interés, montos otorgados y desempeño posterior del crédito.
#
# Desde una perspectiva de negocio, este dataset permite analizar:
#
# - Factores asociados a la aprobación de créditos.
# - Comportamiento de pago de los prestatarios.
# - Riesgo de incumplimiento.
# - Evolución de la cartera de préstamos.
# - Rentabilidad y desempeño de los créditos otorgados.
#
# La información resulta especialmente relevante para la construcción de modelos de riesgo crediticio, segmentación de clientes y análisis de comportamiento financiero.
#
# Dentro del ciclo de vida del crédito, el dataset representa la etapa posterior a la aprobación y desembolso del préstamo.
#
# ---
#
# ### Rol dentro de la arquitectura
#
# Dentro de la arquitectura Lakehouse, Accepted Loans constituye una fuente transaccional principal para el análisis del ciclo de vida completo de los créditos otorgados.
#
# Su información alimenta procesos relacionados con:
#
# - Perfilamiento de clientes.
# - Análisis de riesgo.
# - Seguimiento de préstamos.
# - Evaluación de desempeño financiero.
# - Construcción de indicadores de cartera.
#
# Arquitectónicamente, el dataset participa en las siguientes capas:
#
# Accepted Loans
#
# ↓
#
# Bronze
# (Ingesta cruda)
#
# ↓
#
# Silver
# (Limpieza y normalización)
#
# ↓
#
# Intermediate
# (Modelado dimensional)
#
# ↓
#
# Gold
# (Métricas de riesgo y comportamiento)
#
# ↓
#
# Diamond
# (Fuente única de verdad corporativa)
#
# El dataset servirá como base para dimensiones relacionadas con clientes y créditos, así como para tablas de hechos orientadas al análisis de riesgo y desempeño financiero.

# %% [markdown]
# # 1. Importación de librerías
#
# Se cargan las librerías necesarias para el análisis exploratorio de datos.

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)

# %% [markdown]
# # 2. Carga del Dataset
#
# Se carga el dataset para realizar el análisis exploratorio y comprender su estructura, calidad y relevancia dentro del dominio de negocio.

# %%
df = pd.read_csv("../../../data/raw/lendingClub/accepted_2007_to_2018Q4.csv")

print(f"Filas: {df.shape[0]}")
print(f"Columnas: {df.shape[1]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("../../../data/raw/lendingClub/accepted_2007_to_2018Q4.csv")
#       2
#       3 print(f"Filas: {df.shape[0]}")
#       4 print(f"Columnas: {df.shape[1]}")
#
# ...

# %% [markdown]
# # 3. Tamaño del Dataset
#
# El dataset `Accepted Loans` contiene información histórica de préstamos aprobados por Lending Club entre los años 2007 y 2018.
#
# ## Dimensiones Generales
#
# | Métrica | Valor |
# |----------|---------|
# | Filas | 2,260,701 |
# | Columnas | 151 |
#
# ---
#
# ## Interpretación
#
# El volumen de información evidencia que se trata de una fuente transaccional de gran escala orientada al análisis del ciclo de vida de créditos otorgados.
#
# Cada registro representa un préstamo aprobado por Lending Club, incorporando información relacionada con:
#
# - Características del solicitante.
# - Condiciones del crédito.
# - Información financiera.
# - Historial crediticio.
# - Estado del préstamo.
# - Comportamiento de pago.
# - Recuperación de cartera.
#
# ---
#
# ## Características Generales
#
# El dataset integra información proveniente de múltiples etapas del proceso crediticio:
#
# ### Originación
#
# Información disponible al momento de evaluar la solicitud:
#
# - Ingresos.
# - Empleo.
# - Endeudamiento.
# - Calificación de riesgo.
# - Monto solicitado.
#
# ### Aprobación
#
# Información asociada a la decisión crediticia:
#
# - Monto aprobado.
# - Tasa de interés.
# - Plazo del préstamo.
# - Categoría de riesgo.
#
# ### Seguimiento
#
# Información generada durante la vida del crédito:
#
# - Pagos realizados.
# - Saldo pendiente.
# - Estado actual.
# - Incumplimientos.
#
# ---
#
# ## Relevancia para el Negocio
#
# Accepted Loans constituye la principal fuente de información para comprender el comportamiento de los créditos efectivamente desembolsados.
#
# El dataset permite responder preguntas relacionadas con:
#
# - ¿Qué perfiles de clientes reciben créditos?
# - ¿Qué factores influyen en el incumplimiento?
# - ¿Cómo evoluciona la cartera de préstamos?
# - ¿Cuáles son los niveles de riesgo asociados a cada segmento?
#
# ---
#
# ## Relevancia para Riesgo Crediticio
#
# La amplitud de variables disponibles convierte este dataset en una fuente altamente valiosa para el desarrollo de modelos predictivos de riesgo.
#
# Entre los principales casos de uso se encuentran:
#
# - Predicción de incumplimiento.
# - Segmentación de clientes.
# - Scoring crediticio.
# - Análisis de mora.
# - Evaluación de desempeño de cartera.
#
# ---
#
# ## Consideraciones para Ingeniería de Datos
#
# Con más de 2.2 millones de registros y 151 variables, Accepted Loans constituye una fuente de alta dimensionalidad que requerirá procesos rigurosos de:
#
# - Perfilamiento de datos.
# - Gestión de valores faltantes.
# - Normalización de atributos.
# - Selección de variables.
# - Control de calidad.
#
# Dentro de la arquitectura Lakehouse, este dataset funcionará como una de las principales fuentes para la construcción de dimensiones de clientes y hechos asociados al comportamiento crediticio.

# %% [markdown]
# # 4. Vista Preliminar
#
# Se inspeccionan los primeros registros del dataset con el objetivo de comprender su estructura, contenido y nivel de granularidad.
#
# ## Observaciones Iniciales
#
# La muestra evidencia que cada registro representa un préstamo aprobado por Lending Club.
#
# El dataset almacena información relacionada con el perfil del solicitante, las condiciones financieras del crédito, el historial crediticio del cliente y el desempeño posterior del préstamo.
#
# La información cubre distintas etapas del ciclo de vida crediticio, desde la originación hasta el cierre o estado actual del préstamo.
#
# ---
#
# ## Variables Observadas
#
# | Variable | Descripción |
# |-----------|-------------|
# | id | Identificador único del préstamo |
# | loan_amnt | Monto solicitado por el cliente |
# | funded_amnt | Monto efectivamente financiado |
# | term | Duración del préstamo |
# | int_rate | Tasa de interés aplicada |
# | installment | Valor de la cuota periódica |
# | grade | Categoría general de riesgo |
# | sub_grade | Subcategoría de riesgo |
# | annual_inc | Ingreso anual declarado |
# | home_ownership | Tipo de propiedad de vivienda |
# | verification_status | Estado de verificación de ingresos |
# | loan_status | Estado actual del préstamo |
# | purpose | Motivo del préstamo |
# | dti | Relación deuda-ingreso (Debt-to-Income Ratio) |
# | fico_range_low / fico_range_high | Rango de puntaje crediticio FICO |
#
# ---
#
# ## Hallazgos Iniciales
#
# La estructura observada permite identificar tres grandes grupos de información:
#
# ### Perfil del Solicitante
#
# Incluye variables relacionadas con las características socioeconómicas del cliente:
#
# - annual_inc
# - emp_length
# - home_ownership
# - verification_status
#
# Estas variables permiten caracterizar la capacidad financiera y estabilidad económica del prestatario.
#
# ---
#
# ### Condiciones del Crédito
#
# Incluye información relacionada con el préstamo otorgado:
#
# - loan_amnt
# - funded_amnt
# - term
# - int_rate
# - installment
#
# Estas variables describen las condiciones financieras bajo las cuales se aprobó el crédito.
#
# ---
#
# ### Riesgo Crediticio
#
# El dataset incorpora múltiples indicadores de riesgo:
#
# - grade
# - sub_grade
# - fico_range_low
# - fico_range_high
# - dti
# - delinq_2yrs
#
# Estas variables son utilizadas tradicionalmente para evaluar la probabilidad de incumplimiento de un cliente.
#
# ---
#
# ### Seguimiento del Préstamo
#
# Se observan variables asociadas al comportamiento posterior del crédito:
#
# - loan_status
# - total_pymnt
# - total_rec_prncp
# - total_rec_int
# - recoveries
#
# Estas variables permiten analizar el desempeño financiero de la cartera y el comportamiento de pago de los prestatarios.
#
# ---
#
# ## Primera Hipótesis de Granularidad
#
# A partir de los registros observados se plantea la siguiente hipótesis:
#
# **1 registro = 1 préstamo aprobado**
#
# Esta hipótesis será validada posteriormente mediante el análisis de identificadores y cardinalidad.
#
# ---
#
# ## Relación con el Negocio
#
# El dataset representa el universo de créditos aprobados por Lending Club entre 2007 y 2018.
#
# Su contenido permite analizar:
#
# - Factores asociados a la aprobación de créditos.
# - Comportamiento de pago de los clientes.
# - Evolución de la cartera.
# - Riesgo crediticio.
# - Recuperación de préstamos en incumplimiento.
#
# ---
#
# ## Potenciales Indicadores
#
# La estructura observada permitirá construir métricas relacionadas con:
#
# - Tasa de incumplimiento.
# - Monto promedio financiado.
# - Distribución de riesgo por categoría.
# - Rendimiento de la cartera.
# - Recuperación de préstamos.
# - Comportamiento de pago.
# - Segmentación de clientes según riesgo crediticio.
#
# ---
#
# ## Conclusión Preliminar
#
# Accepted Loans constituye una fuente altamente rica para el análisis financiero y crediticio, integrando información de originación, evaluación de riesgo y desempeño posterior del préstamo dentro de una única estructura de datos.

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # 5. Estructura General
#
# Se analiza la composición estructural del dataset para comprender los tipos de datos utilizados, evaluar la complejidad del esquema y estimar el esfuerzo requerido para los procesos de transformación y modelado analítico.
#
# ---
#
# ## Resumen Estructural
#
# | Métrica | Valor |
# |----------|---------|
# | Registros | 2,260,701 |
# | Columnas | 151 |
# | Variables Numéricas | 113 |
# | Variables Categóricas | 38 |
# | Tipos de Datos Distintos | 3 |
#
# ---
#
# ## Distribución de Tipos de Datos
#
# | Tipo de Dato | Cantidad |
# |--------------|----------|
# | float64 | 113 |
# | string | 37 |
# | object | 1 |
#
# ---
#
# ## Interpretación
#
# Accepted Loans presenta una estructura de alta dimensionalidad, incorporando una gran variedad de atributos financieros, crediticios y operativos relacionados con el ciclo de vida completo de los préstamos otorgados.
#
# La predominancia de variables numéricas evidencia una fuerte orientación hacia el análisis cuantitativo del riesgo crediticio y el desempeño financiero.
#
# ---
#
# ## Componentes Principales
#
# ### Variables Financieras
#
# El dataset contiene un amplio conjunto de variables relacionadas con montos, pagos y saldos financieros.
#
# Ejemplos:
#
# - loan_amnt
# - funded_amnt
# - installment
# - annual_inc
# - total_pymnt
# - total_rec_prncp
# - total_rec_int
# - recoveries
#
# Estas variables permiten analizar el desempeño económico de los préstamos y la rentabilidad de la cartera.
#
# ---
#
# ### Variables de Riesgo
#
# Se identifican múltiples atributos utilizados tradicionalmente en modelos de riesgo crediticio.
#
# Ejemplos:
#
# - fico_range_low
# - fico_range_high
# - grade
# - sub_grade
# - dti
# - delinq_2yrs
# - pub_rec
# - inq_last_6mths
#
# Estas variables permiten caracterizar la solvencia financiera de los prestatarios.
#
# ---
#
# ### Variables Operativas
#
# El dataset incorpora información asociada a la administración y seguimiento de los préstamos.
#
# Ejemplos:
#
# - loan_status
# - issue_d
# - last_pymnt_d
# - next_pymnt_d
# - last_credit_pull_d
#
# Estas variables permiten monitorear la evolución temporal de los créditos.
#
# ---
#
# ### Variables de Recuperación
#
# Se observan atributos relacionados con procesos de cobranza y recuperación de cartera.
#
# Ejemplos:
#
# - recoveries
# - collection_recovery_fee
# - settlement_amount
# - settlement_percentage
#
# La presencia de estas variables amplía significativamente las capacidades analíticas del dataset.
#
# ---
#
# ### Variables de Aplicaciones Conjuntas
#
# El esquema incorpora campos específicos para créditos con múltiples solicitantes.
#
# Ejemplos:
#
# - annual_inc_joint
# - dti_joint
# - verification_status_joint
#
# Estas variables sugieren la existencia de diferentes modalidades de originación crediticia.
#
# ---
#
# ## Complejidad del Dataset
#
# Con 151 variables, Accepted Loans presenta una complejidad considerablemente superior a la observada en los datasets de Home Credit analizados previamente.
#
# La amplitud de información disponible permite abordar múltiples dominios analíticos:
#
# - Originación crediticia.
# - Scoring de riesgo.
# - Seguimiento de cartera.
# - Cobranza.
# - Recuperación financiera.
# - Segmentación de clientes.
#
# ---
#
# ## Implicaciones para Ingeniería de Datos
#
# La alta dimensionalidad del dataset requerirá procesos robustos de:
#
# - Perfilamiento de datos.
# - Gestión de valores faltantes.
# - Estandarización de variables.
# - Selección de atributos relevantes.
# - Optimización de almacenamiento y procesamiento.
#
# Debido a su tamaño superior a 3 GB en memoria, el procesamiento distribuido mediante Spark constituye una alternativa adecuada para futuras etapas de transformación.
#
# ---
#
# ## Hipótesis Inicial de Modelado
#
# La estructura observada sugiere que el dataset podría alimentar simultáneamente:
#
# ### Dimensiones
#
# - Cliente.
# - Tiempo.
# - Riesgo Crediticio.
#
# ### Hechos
#
# - Solicitudes de crédito.
# - Desempeño financiero.
# - Recuperación de cartera.
#
# Estas hipótesis serán validadas posteriormente durante el análisis de relaciones y diseño del modelo dimensional.
#
# ---
#
# ## Conclusión
#
# Accepted Loans constituye una fuente analítica de alta riqueza informacional, integrando variables financieras, crediticias, operativas y de recuperación dentro de una única estructura.
#
# Su amplitud y profundidad lo convierten en un candidato ideal para el desarrollo de modelos de riesgo crediticio, comportamiento financiero y análisis avanzado de cartera.

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.dtypes.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.dtypes.value_counts()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # 6. Identificación de Claves
#
# Se identifican:
#
# - Clave primaria
# - Claves foráneas
# - Relaciones con otros datasets

# %%
len(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 len(df)
#
# NameError: name 'df' is not defined

# %%
df["id"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df["id"].nunique()
#
# NameError: name 'df' is not defined

# %%
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.duplicated().sum()
#
# NameError: name 'df' is not defined

# %%
df["member_id"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df["member_id"].nunique()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Interpretación
#
# El análisis de la estructura del dataset evidencia la existencia de un identificador único asociado a cada préstamo registrado dentro de la plataforma Lending Club.
#
# La correcta identificación de las claves resulta fundamental para garantizar la integridad de los procesos analíticos y facilitar la construcción posterior del modelo dimensional.
#
# ---
#
# ### Clave Primaria
#
# #### id
#
# La columna `id` representa el identificador único asignado por Lending Club a cada préstamo aprobado.
#
# Características:
#
# - Identificador único del préstamo.
# - Permite distinguir cada operación crediticia.
# - No presenta significado de negocio adicional.
# - Facilita la trazabilidad del crédito durante todo su ciclo de vida.
#
# Por lo tanto:
#
# | Columna | Rol |
# |----------|---------|
# | id | Primary Key (PK) |
#
# ---
#
# ### member_id
#
# La variable `member_id` aparece dentro del esquema histórico de Lending Club como identificador asociado al cliente o miembro de la plataforma.
#
# Sin embargo, se observa una gran cantidad de valores faltantes en las versiones más recientes del dataset, por lo que no constituye una clave primaria confiable para procesos analíticos.
#
# Su utilización deberá evaluarse posteriormente durante el análisis de calidad de datos.
#
# ---
#
# ### Granularidad del Dataset
#
# A partir de la información observada se plantea la siguiente definición de grano:
#
# **1 registro = 1 préstamo aprobado**
#
# Cada fila representa una operación crediticia específica otorgada por Lending Club.
#
# La información contenida incluye:
#
# - Características del solicitante.
# - Condiciones del crédito.
# - Variables de riesgo.
# - Historial de pagos.
# - Estado del préstamo.
# - Procesos de recuperación.
#
# ---
#
# ### Relación con el Modelo Dimensional
#
# El identificador `id` permitirá construir futuras entidades relacionadas con:
#
# #### Dimensiones
#
# - Dimensión Crédito (DIM_CREDIT)
#
# #### Tablas de Hechos
#
# - FACT_CREDIT_APPLICATION
# - FACT_CREDIT_PERFORMANCE
# - FACT_COLLECTIONS
#
# ---
#
# ### Integridad de Registros
#
# Se recomienda validar posteriormente:
#
# | Validación | Objetivo |
# |------------|-----------|
# | id UNIQUE | Garantizar unicidad |
# | id NOT NULL | Garantizar integridad |
# | Registros duplicados | Detectar inconsistencias |
#
# Estas verificaciones permitirán confirmar formalmente la integridad estructural del dataset.
#
# ---
#
# ### Conclusión
#
# La columna `id` constituye la clave primaria natural del dataset y confirma que la granularidad de Accepted Loans se encuentra definida a nivel de préstamo individual.
#
# Esta característica simplifica significativamente la construcción de modelos analíticos orientados al análisis de riesgo crediticio, comportamiento financiero y desempeño de cartera.

# %% [markdown]
# # 7. Calidad de Datos
#
# Se analiza la completitud de la información y posibles problemas de calidad.

# %%
null_percentage = (
    df.isnull()
      .mean()
      .mul(100)
      .sort_values(ascending=False)
)

null_percentage.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 null_percentage = (
# ----> 2     df.isnull()
#       3       .mean()
#       4       .mul(100)
#       5       .sort_values(ascending=False)
#
# NameError: name 'df' is not defined

# %%
high_nulls = null_percentage[null_percentage > 50]

medium_nulls = null_percentage[
    (null_percentage > 20)
    & (null_percentage <= 50)
]

low_nulls = null_percentage[
    (null_percentage > 0)
    & (null_percentage <= 20)
]

print("Columnas > 50%:", len(high_nulls))
print("Columnas entre 20%-50%:", len(medium_nulls))
print("Columnas < 20%:", len(low_nulls))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 high_nulls = null_percentage[null_percentage > 50]
#       2
#       3 medium_nulls = null_percentage[
#       4     (null_percentage > 20)
#
# NameError: name 'null_percentage' is not defined

# %% [markdown]
# ## Interpretación
#
# Se realizó un análisis de completitud con el objetivo de identificar la presencia de valores faltantes y evaluar su impacto sobre los procesos analíticos posteriores.
#
# ---
#
# ### Resumen General
#
# | Categoría | Cantidad |
# |------------|----------|
# | Columnas > 50% nulos | 44 |
# | Columnas entre 20% y 50% | 14 |
# | Columnas < 20% | 92 |
#
# ---
#
# ## Variables con Mayor Porcentaje de Valores Faltantes
#
# | Variable | % Nulos |
# |------------|---------|
# | member_id | 100.00% |
# | orig_projected_additional_accrued_interest | 99.62% |
# | hardship_reason | 99.52% |
# | hardship_payoff_balance_amount | 99.52% |
# | hardship_last_payment_amount | 99.52% |
# | payment_plan_start_date | 99.52% |
# | hardship_type | 99.52% |
# | hardship_status | 99.52% |
# | hardship_start_date | 99.52% |
# | deferral_term | 99.52% |
# | hardship_amount | 99.52% |
# | hardship_dpd | 99.52% |
# | hardship_loan_status | 99.52% |
# | hardship_length | 99.52% |
# | hardship_end_date | 99.52% |
# | settlement_status | 98.49% |
# | debt_settlement_flag_date | 98.49% |
# | settlement_term | 98.49% |
# | settlement_percentage | 98.49% |
# | settlement_date | 98.49% |
#
# ---
#
# ## Interpretación de Negocio
#
# Los resultados muestran que la mayoría de los valores faltantes se concentran en variables asociadas a procesos especiales de administración de cartera.
#
# Estas variables no forman parte del flujo estándar de originación y seguimiento de préstamos, sino que se activan únicamente bajo circunstancias particulares.
#
# ---
#
# ### Programas de Hardship
#
# Las variables:
#
# - hardship_reason
# - hardship_status
# - hardship_amount
# - hardship_dpd
# - hardship_start_date
# - hardship_end_date
#
# corresponden a programas de alivio financiero ofrecidos a clientes con dificultades para cumplir sus obligaciones.
#
# El hecho de que más del 99% de los registros presenten valores nulos indica que únicamente una pequeña fracción de los prestatarios participó en este tipo de programas.
#
# Por lo tanto, estos valores faltantes no representan errores de calidad de datos.
#
# ---
#
# ### Procesos de Debt Settlement
#
# Las variables:
#
# - settlement_status
# - settlement_date
# - settlement_amount
# - settlement_percentage
# - settlement_term
#
# se relacionan con acuerdos de liquidación o recuperación de deuda.
#
# La alta proporción de valores nulos resulta esperada debido a que la mayoría de los préstamos no ingresan en procesos de negociación de deuda.
#
# ---
#
# ### member_id
#
# La variable member_id presenta un 100% de valores faltantes.
#
# Este comportamiento sugiere que el atributo dejó de utilizarse en versiones recientes del dataset o fue eliminado durante procesos de anonimización.
#
# Debido a su ausencia total de información, la variable constituye una candidata natural para exclusión en futuras etapas de transformación.
#
# ---
#
# ## Hallazgos Relevantes
#
# ### Alta Dimensionalidad
#
# El dataset contiene:
#
# - 151 variables totales.
# - 44 columnas con más del 50% de valores faltantes.
#
# Esto indica la presencia de múltiples atributos especializados asociados a escenarios específicos del negocio.
#
# ---
#
# ### Calidad Operativa
#
# A pesar del elevado número de columnas con valores faltantes, la evidencia sugiere que gran parte de estos nulos responden a reglas de negocio válidas y no a problemas de captura o almacenamiento.
#
# ---
#
# ### Clasificación Inicial
#
# Las variables pueden agruparse en:
#
# #### Variables Core
#
# Información presente para la mayoría de los préstamos:
#
# - loan_amnt
# - funded_amnt
# - int_rate
# - installment
# - annual_inc
# - loan_status
# - fico_range_low
# - fico_range_high
#
# #### Variables Condicionales
#
# Información disponible únicamente en escenarios específicos:
#
# - hardship_*
# - settlement_*
# - sec_app_*
# - annual_inc_joint
# - dti_joint
#
# ---
#
# ## Implicaciones para la Arquitectura Lakehouse
#
# ### Bronze
#
# Todos los atributos deberán conservarse para mantener la trazabilidad completa de la fuente original.
#
# ### Silver
#
# Será necesario clasificar los valores faltantes entre:
#
# - Nulos esperados por reglas de negocio.
# - Nulos potencialmente problemáticos.
#
# Asimismo, se evaluará la relevancia analítica de las columnas con más del 90% de valores faltantes.
#
# ### Gold
#
# Las variables con alta completitud y valor analítico constituirán la base para la construcción de indicadores financieros y modelos de riesgo.
#
# ---
#
# ## Conclusión
#
# Accepted Loans presenta un volumen considerable de valores faltantes concentrados principalmente en procesos excepcionales de hardship y debt settlement.
#
# La evidencia observada indica que la mayoría de estos nulos son consistentes con la lógica de negocio y no representan deficiencias estructurales de calidad de datos.
#
# No obstante, será necesario evaluar cuidadosamente la permanencia de determinadas variables durante las etapas posteriores de modelado y transformación.

# %% [markdown]
# # 8. Detección de Registros Duplicados

# %%
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.duplicated().sum()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Interpretación
#
# Se realizó una validación de duplicidad sobre la totalidad de los registros presentes en el dataset.
#
# ### Resultados
#
# | Métrica | Valor |
# |----------|---------|
# | Registros Totales | 2,260,701 |
# | Registros Duplicados | 0 |
# | Porcentaje de Duplicados | 0% |
#
# ### Hallazgos
#
# No se identificaron registros completamente duplicados dentro del dataset.
#
# Este resultado confirma que cada préstamo aprobado se encuentra representado por un único registro dentro de la fuente de datos.
#
# ### Conclusión
#
# La ausencia de duplicados fortalece la confiabilidad del dataset para procesos de análisis financiero, modelado de riesgo y construcción de indicadores de cartera.

# %% [markdown]
# # 9. Variables de Negocio Relevantes
#
# Con el objetivo de comprender los principales procesos de negocio representados dentro del dataset, se seleccionó un conjunto de variables consideradas estratégicas para el análisis del ciclo de vida de los préstamos otorgados por Lending Club.
#
# ---
#
# ## Vista de Variables de Negocio
#
# | loan_amnt | funded_amnt | term | int_rate | installment | purpose |
# |------------|------------|---------|----------|------------|------------|
# | 3600.0 | 3600.0 | 36 months | 13.99 | 123.03 | debt_consolidation |
# | 24700.0 | 24700.0 | 36 months | 11.99 | 820.28 | small_business |
# | 20000.0 | 20000.0 | 60 months | 10.78 | 432.66 | home_improvement |
# | 35000.0 | 35000.0 | 60 months | 14.85 | 829.90 | debt_consolidation |
# | 10400.0 | 10400.0 | 60 months | 22.45 | 289.91 | major_purchase |
#
# ---
#
# ## Interpretación de las Variables
#
# ### loan_amnt
#
# Representa el monto solicitado por el cliente al momento de realizar la solicitud de crédito.
#
# Permite analizar:
#
# - Tamaño promedio de los préstamos.
# - Distribución de montos financiados.
# - Segmentación de clientes según necesidades de financiamiento.
#
# ---
#
# ### funded_amnt
#
# Corresponde al monto efectivamente aprobado y desembolsado por Lending Club.
#
# Esta variable resulta fundamental para:
#
# - Medir el volumen de crédito otorgado.
# - Analizar diferencias entre monto solicitado y financiado.
# - Construir indicadores de cartera.
#
# En los registros observados se aprecia que el monto financiado coincide con el monto solicitado.
#
# ---
#
# ### term
#
# Indica la duración contractual del préstamo.
#
# Valores observados:
#
# - 36 months
# - 60 months
#
# Esta variable permite estudiar:
#
# - Preferencias de financiamiento de los clientes.
# - Impacto del plazo sobre el riesgo crediticio.
# - Relación entre duración e incumplimiento.
#
# ---
#
# ### int_rate
#
# Representa la tasa de interés aplicada al préstamo.
#
# Se observa variabilidad entre los distintos registros, reflejando diferencias en el perfil de riesgo de los prestatarios.
#
# Esta variable es clave para:
#
# - Determinar el costo del crédito.
# - Evaluar rentabilidad de la cartera.
# - Analizar estrategias de pricing crediticio.
#
# ---
#
# ### installment
#
# Corresponde al valor de la cuota periódica que el prestatario debe pagar.
#
# La cuota depende de:
#
# - Monto financiado.
# - Tasa de interés.
# - Plazo del crédito.
#
# Su análisis permite estudiar la capacidad de pago de los clientes y el esfuerzo financiero asociado a cada préstamo.
#
# ---
#
# ### purpose
#
# Describe el motivo principal por el cual el cliente solicita el crédito.
#
# Algunos ejemplos observados son:
#
# - debt_consolidation
# - small_business
# - home_improvement
# - major_purchase
#
# Esta variable resulta especialmente valiosa para procesos de segmentación y análisis de comportamiento.
#
# ---
#
# ## Agrupación por Procesos de Negocio
#
# Las variables analizadas representan principalmente la fase de originación del crédito.
#
# ### Originación
#
# Variables:
#
# - loan_amnt
# - funded_amnt
# - term
# - int_rate
# - installment
#
# Pregunta de negocio:
#
# ¿Qué condiciones financieras fueron otorgadas al cliente?
#
# ---
#
# ### Destino del Crédito
#
# Variables:
#
# - purpose
#
# Pregunta de negocio:
#
# ¿Para qué necesitan financiamiento los clientes?
#
# ---
#
# ## Hallazgos Iniciales
#
# A partir de los registros observados pueden identificarse algunos patrones preliminares:
#
# - El monto financiado coincide con el monto solicitado en los ejemplos analizados.
# - Los préstamos presentan principalmente plazos de 36 y 60 meses.
# - La consolidación de deuda aparece como uno de los motivos más frecuentes para solicitar financiamiento.
# - Existe variabilidad importante en las tasas de interés, sugiriendo mecanismos de evaluación de riesgo diferenciados.
#
# ---
#
# ## Relevancia para el Proyecto
#
# Estas variables constituyen la base para futuros análisis relacionados con:
#
# - Riesgo crediticio.
# - Segmentación de clientes.
# - Comportamiento financiero.
# - Rentabilidad de cartera.
# - Predicción de incumplimiento.
#
# Asimismo, representan atributos potenciales para la construcción de dimensiones y hechos dentro del modelo dimensional del proyecto.
#
# ---
#
# ## Conclusión
#
# Las variables analizadas permiten caracterizar las condiciones bajo las cuales Lending Club otorgó los préstamos y proporcionan información esencial para comprender tanto el comportamiento de los clientes como las estrategias de originación crediticia de la organización.

# %%
important_cols = [
    'loan_amnt',
    'funded_amnt',
    'term',
    'int_rate',
    'installment',
    'purpose'
]

df[important_cols].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       6     'installment',
#       7     'purpose'
#       8 ]
#       9
# ---> 10 df[important_cols].head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # 10. Variables Categóricas

# %%
categorical_columns = df.select_dtypes(include=["object"])

categorical_columns.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 categorical_columns = df.select_dtypes(include=["object"])
#       2
#       3 categorical_columns.columns.tolist()
#
# NameError: name 'df' is not defined

# %%
for col in categorical_columns.columns:
    print(f"{col}: {df[col].nunique()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 for col in categorical_columns.columns:
#       2     print(f"{col}: {df[col].nunique()}")
#
# NameError: name 'categorical_columns' is not defined

# %% [markdown]
# ## Interpretación
#
# # 10. Variables Categóricas
#
# Con el objetivo de comprender la diversidad de categorías presentes en el dataset, se analizó el número de valores únicos para las principales variables categóricas.
#
# ---
#
# ## Cardinalidad de Variables Categóricas
#
# | Variable | Valores Únicos |
# |-----------|-----------|
# | id | 2,260,701 |
# | term | 2 |
# | grade | 7 |
# | sub_grade | 35 |
# | emp_title | 512,694 |
# | emp_length | 11 |
# | home_ownership | 6 |
# | verification_status | 3 |
# | issue_d | 139 |
# | loan_status | 9 |
# | pymnt_plan | 2 |
# | url | 2,260,668 |
# | desc | 124,500 |
# | purpose | 14 |
# | title | 63,154 |
# | zip_code | 956 |
# | addr_state | 51 |
# | earliest_cr_line | 754 |
# | initial_list_status | 2 |
# | last_pymnt_d | 136 |
# | next_pymnt_d | 106 |
# | last_credit_pull_d | 141 |
# | application_type | 2 |
# | verification_status_joint | 3 |
# | sec_app_earliest_cr_line | 663 |
# | debt_settlement_flag | 2 |
# | debt_settlement_flag_date | 83 |
# | settlement_status | 3 |
# | settlement_date | 90 |
#
# ---
#
# ## Interpretación
#
# Las variables categóricas presentan distintos niveles de cardinalidad, lo que permite clasificarlas en grupos según su comportamiento analítico.
#
# ---
#
# ### Baja Cardinalidad
#
# Variables con pocas categorías y alto valor analítico.
#
# Ejemplos:
#
# - term (2)
# - grade (7)
# - home_ownership (6)
# - verification_status (3)
# - loan_status (9)
# - purpose (14)
# - application_type (2)
# - debt_settlement_flag (2)
#
# Estas variables resultan especialmente útiles para:
#
# - Segmentación de clientes.
# - Construcción de indicadores.
# - Modelos predictivos.
# - Análisis de riesgo.
#
# ---
#
# ### Cardinalidad Media
#
# Variables con un número moderado de categorías.
#
# Ejemplos:
#
# - sub_grade (35)
# - addr_state (51)
# - issue_d (139)
# - last_pymnt_d (136)
# - last_credit_pull_d (141)
# - earliest_cr_line (754)
#
# Estas variables permiten realizar análisis temporales y geográficos más detallados.
#
# ---
#
# ### Alta Cardinalidad
#
# Variables con un número muy elevado de categorías.
#
# Ejemplos:
#
# - emp_title (512,694)
# - title (63,154)
# - desc (124,500)
# - zip_code (956)
#
# Estas variables presentan desafíos para el modelado debido a la dispersión de valores y generalmente requieren procesos de agrupación, estandarización o codificación especializada.
#
# ---
#
# ### Variables Identificadoras
#
# Algunas variables presentan cardinalidad prácticamente única por registro.
#
# Ejemplos:
#
# - id
# - url
#
# Estas columnas cumplen principalmente funciones de identificación y trazabilidad, por lo que su valor analítico directo es limitado.
#
# ---
#
# ## Hallazgos Relevantes
#
# ### Sistema de Clasificación Crediticia
#
# Las variables:
#
# - grade
# - sub_grade
#
# constituyen el mecanismo principal de clasificación de riesgo utilizado por Lending Club.
#
# La existencia de:
#
# - 7 categorías generales
# - 35 subcategorías
#
# sugiere un modelo interno de evaluación crediticia relativamente granular.
#
# ---
#
# ### Información Geográfica
#
# Las variables:
#
# - addr_state
# - zip_code
#
# permiten incorporar componentes regionales al análisis del riesgo y comportamiento financiero.
#
# ---
#
# ### Información Laboral
#
# La variable:
#
# - emp_title
#
# presenta más de 500 mil valores distintos, reflejando una gran diversidad ocupacional entre los prestatarios.
#
# Sin embargo, esta alta cardinalidad requerirá procesos de normalización para futuros análisis.
#
# ---
#
# ### Estados del Crédito
#
# La variable:
#
# - loan_status
#
# contiene 9 categorías distintas que describen la situación actual de cada préstamo.
#
# Esta variable constituye uno de los atributos más relevantes para la construcción de modelos de riesgo e incumplimiento.
#
# ---
#
# ## Implicaciones para el Modelado
#
# Las variables de baja y media cardinalidad representan candidatas naturales para dimensiones analíticas dentro del modelo dimensional.
#
# Por otro lado, las variables de muy alta cardinalidad deberán ser evaluadas cuidadosamente para evitar explosiones de dimensionalidad y problemas de rendimiento.
#
# ---
#
# ## Conclusión
#
# Accepted Loans presenta una combinación equilibrada de variables categóricas operativas, financieras y de riesgo.
#
# Las categorías observadas permiten capturar aspectos fundamentales relacionados con la evaluación crediticia, el comportamiento de los prestatarios y la administración de la cartera de préstamos.

# %% [markdown]
# # 11. Relaciones del Dataset
#
# El análisis de las variables permite identificar diversas relaciones de negocio que describen el ciclo de vida completo de los préstamos otorgados por Lending Club.
#
# Estas relaciones constituyen la base para futuros procesos de modelado dimensional, análisis de riesgo y construcción de indicadores financieros.
#
# ---
#
# ## Relación entre Monto Solicitado y Monto Financiado
#
# Variables:
#
# - loan_amnt
# - funded_amnt
#
# Interpretación:
#
# El monto financiado representa la cantidad efectivamente aprobada y desembolsada al prestatario.
#
# Esta relación permite analizar:
#
# - Diferencias entre solicitud y aprobación.
# - Políticas de financiamiento.
# - Niveles de exposición crediticia.
#
# Pregunta de negocio:
#
# ¿Cuánto financia realmente la entidad respecto al monto solicitado por el cliente?
#
# ---
#
# ## Relación entre Riesgo y Tasa de Interés
#
# Variables:
#
# - grade
# - sub_grade
# - int_rate
#
# Interpretación:
#
# Lending Club asigna categorías de riesgo a cada prestatario y utiliza dicha clasificación para determinar la tasa de interés aplicada.
#
# Pregunta de negocio:
#
# ¿Cómo influye el nivel de riesgo del cliente sobre el costo del crédito?
#
# ---
#
# ## Relación entre Capacidad Financiera y Crédito
#
# Variables:
#
# - annual_inc
# - dti
# - loan_amnt
# - installment
#
# Interpretación:
#
# Estas variables permiten evaluar la capacidad de pago del prestatario frente a las obligaciones adquiridas.
#
# Pregunta de negocio:
#
# ¿Existe relación entre ingresos, endeudamiento y monto financiado?
#
# ---
#
# ## Relación entre Historial Crediticio y Riesgo
#
# Variables:
#
# - fico_range_low
# - fico_range_high
# - delinq_2yrs
# - pub_rec
# - inq_last_6mths
# - grade
#
# Interpretación:
#
# El historial financiero del cliente influye directamente sobre la clasificación de riesgo asignada por la entidad.
#
# Pregunta de negocio:
#
# ¿Cómo afecta el comportamiento crediticio previo a la evaluación del préstamo?
#
# ---
#
# ## Relación entre Condiciones del Crédito y Desempeño
#
# Variables:
#
# - term
# - int_rate
# - installment
# - loan_status
#
# Interpretación:
#
# Las condiciones otorgadas al préstamo pueden influir en la probabilidad de incumplimiento y en el desempeño posterior de la cartera.
#
# Pregunta de negocio:
#
# ¿Qué combinaciones de plazo y tasa generan mayores niveles de riesgo?
#
# ---
#
# ## Relación entre Estado del Préstamo y Recuperación
#
# Variables:
#
# - loan_status
# - recoveries
# - collection_recovery_fee
# - settlement_status
# - settlement_amount
#
# Interpretación:
#
# Estas variables describen los procesos de cobranza y recuperación aplicados a préstamos con dificultades de pago.
#
# Pregunta de negocio:
#
# ¿Cuál es la efectividad de los procesos de recuperación de cartera?
#
# ---
#
# ## Relación Temporal del Crédito
#
# Variables:
#
# - issue_d
# - earliest_cr_line
# - last_pymnt_d
# - last_credit_pull_d
#
# Interpretación:
#
# Permiten reconstruir la línea temporal completa del préstamo desde la originación hasta el estado más reciente disponible.
#
# Pregunta de negocio:
#
# ¿Cómo evoluciona el comportamiento del crédito a lo largo del tiempo?
#
# ---
#
# ## Relación Geográfica
#
# Variables:
#
# - addr_state
# - zip_code
# - loan_status
#
# Interpretación:
#
# Permiten analizar patrones regionales de aprobación, comportamiento y riesgo.
#
# Pregunta de negocio:
#
# ¿Existen diferencias significativas en el desempeño de los préstamos según ubicación geográfica?
#
# ---
#
# ## Conclusión
#
# Las relaciones identificadas reflejan el ciclo completo del crédito, integrando información de originación, evaluación de riesgo, comportamiento financiero y recuperación de cartera.
#
# Estas interacciones constituyen la base para futuros análisis predictivos y para la construcción del modelo dimensional de la solución analítica.

# %% [markdown]
# # 12. Conclusiones Técnicas
#
# El análisis exploratorio realizado sobre el dataset Accepted Loans permitió comprender la estructura, calidad y potencial analítico de la información histórica de préstamos otorgados por Lending Club entre 2007 y 2018.
#
# ---
#
# ## Hallazgos Generales
#
# El dataset contiene:
#
# - 2,260,701 registros.
# - 151 variables.
# - Más de 3 GB de información en memoria.
#
# La granularidad identificada corresponde a:
#
# **1 registro = 1 préstamo aprobado**
#
# Esta característica simplifica significativamente los procesos posteriores de integración y modelado.
#
# ---
#
# ## Calidad de Datos
#
# Se identificaron:
#
# - 44 columnas con más del 50% de valores faltantes.
# - 14 columnas entre 20% y 50%.
# - 92 columnas con menos del 20%.
#
# Sin embargo, la mayoría de los valores faltantes corresponden a procesos excepcionales relacionados con:
#
# - Hardship Programs.
# - Debt Settlement.
# - Joint Applications.
#
# Por lo tanto, gran parte de los nulos observados responden a reglas de negocio válidas y no necesariamente a problemas de calidad de datos.
#
# ---
#
# ## Identificadores
#
# La variable:
#
# - id
#
# actúa como identificador único natural del préstamo.
#
# Su utilización permitirá garantizar trazabilidad e integridad durante futuras etapas de transformación.
#
# ---
#
# ## Variables de Mayor Valor Analítico
#
# Se identificaron cinco dominios principales de análisis:
#
# ### Originación
#
# - loan_amnt
# - funded_amnt
# - term
# - int_rate
#
# ### Perfil del Cliente
#
# - annual_inc
# - emp_length
# - home_ownership
#
# ### Riesgo Crediticio
#
# - grade
# - sub_grade
# - fico_range_low
# - fico_range_high
# - dti
#
# ### Desempeño Financiero
#
# - loan_status
# - total_pymnt
# - total_rec_prncp
#
# ### Recuperación de Cartera
#
# - recoveries
# - settlement_status
# - settlement_amount
#
# ---
#
# ## Potencial Analítico
#
# La riqueza de información disponible permite desarrollar iniciativas relacionadas con:
#
# - Scoring crediticio.
# - Predicción de incumplimiento.
# - Segmentación de clientes.
# - Evaluación de cartera.
# - Modelos de cobranza.
# - Análisis de recuperación financiera.
#
# ---
#
# ## Implicaciones para Ingeniería de Datos
#
# Debido al volumen y dimensionalidad del dataset, las etapas posteriores requerirán:
#
# - Procesos robustos de calidad de datos.
# - Normalización de atributos.
# - Gestión eficiente de valores faltantes.
# - Procesamiento distribuido mediante Spark.
# - Estrategias de particionamiento y optimización de almacenamiento.
#
# ---
#
# ## Relación con la Arquitectura Lakehouse
#
# Dentro de la arquitectura propuesta, Accepted Loans constituye una fuente principal para la construcción de activos analíticos relacionados con riesgo y comportamiento crediticio.
#
# Su flujo esperado será:
#
# Accepted Loans
#
# ↓
#
# Bronze
#
# ↓
#
# Silver
#
# ↓
#
# Intermediate
#
# ↓
#
# Gold
#
# ↓
#
# Diamond
#
# ---
#
# ## Relación con el Modelo Dimensional
#
# El dataset contiene información suficiente para alimentar futuras dimensiones y hechos asociados al negocio crediticio.
#
# Entre las entidades potenciales se identifican:
#
# ### Dimensiones
#
# - Cliente
# - Tiempo
# - Riesgo Crediticio
#
# ### Hechos
#
# - Solicitudes de Crédito
# - Desempeño Financiero
# - Recuperación de Cartera
#
# ---
#
# ## Conclusión Final
#
# Accepted Loans representa una fuente de información altamente completa y madura desde la perspectiva financiera.
#
# A diferencia de otros datasets crediticios, incorpora información de originación, evaluación de riesgo, desempeño operativo y recuperación de cartera dentro de una única estructura, convirtiéndose en un activo de gran valor para el desarrollo de soluciones analíticas avanzadas orientadas al riesgo crediticio y la gestión integral de préstamos.
