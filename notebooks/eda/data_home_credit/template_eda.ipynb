# %% [markdown]
# # Home Credit Risk Analysis
#
# ## Dataset: [DATASET_NAME]
#
# ### Objetivo
#
# Analizar la estructura, calidad y relaciones del dataset para comprender su papel dentro de la arquitectura Lakehouse y del modelo dimensional.
#
# ---
#
# ### Contexto del negocio
#
# [DESCRIPCIÓN DEL DATASET]
#
# ---
#
# ### Rol dentro de la arquitectura
#
# [RELACIONES PRINCIPALES]

# %% [markdown]
# # 1. Importación de librerías
#
# Se cargan las librerías necesarias para el análisis exploratorio de datos.

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)

# %% [markdown]
# # 2. Carga del Dataset
#
# Se carga el dataset para realizar el análisis exploratorio y comprender su estructura, calidad y relevancia dentro del dominio de negocio.

# %%
df = pd.read_csv("../../data/raw/[DATASET_FILE].csv")

print(f"Filas: {df.shape[0]}")
print(f"Columnas: {df.shape[1]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("../../data/raw/[DATASET_FILE].csv")
#       2
#       3 print(f"Filas: {df.shape[0]}")
#       4 print(f"Columnas: {df.shape[1]}")
#
# File c:\Users\Coders\Desktop\financial-analytics-keppler\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Coders\Desktop\financial-analytics-keppler\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Coders\Desktop\financial-analytics-keppler\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Coders\Desktop\financial-analytics-keppler\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\Coders\Desktop\financial-analytics-keppler\.venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/raw/[DATASET_FILE].csv'

# %% [markdown]
# # 3. Tamaño del Dataset
#
# ## Resultados
#
# | Métrica | Valor |
# |----------|---------|
# | Filas | [ROWS] |
# | Columnas | [COLUMNS] |
#
# ## Interpretación
#
# [INTERPRETACIÓN GENERAL]

# %% [markdown]
# # 4. Vista preliminar
#
# Se inspeccionan los primeros registros para comprender la estructura general de los datos.

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # 5. Estructura General
#
# Se analiza:
#
# - Tipos de datos
# - Cantidad de columnas
# - Valores nulos
# - Distribución general

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.dtypes.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.dtypes.value_counts()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # 6. Identificación de Claves
#
# Se identifican:
#
# - Clave primaria
# - Claves foráneas
# - Relaciones con otros datasets

# %%
len(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 len(df)
#
# NameError: name 'df' is not defined

# %%
df["PRIMARY_KEY"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df["PRIMARY_KEY"].nunique()
#
# NameError: name 'df' is not defined

# %%
df["PRIMARY_KEY"].duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df["PRIMARY_KEY"].duplicated().sum()
#
# NameError: name 'df' is not defined

# %%
df["FOREIGN_KEY"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df["FOREIGN_KEY"].nunique()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Conclusiones sobre las Claves
#
# ### Clave Primaria
#
# [PK]
#
# ### Clave Foránea
#
# [FK]
#
# ### Cardinalidad
#
# [RELACIÓN]

# %% [markdown]
# # 7. Calidad de Datos
#
# Se analiza la completitud de la información y posibles problemas de calidad.

# %%
null_percentage = (
    df.isnull()
      .mean()
      .mul(100)
      .sort_values(ascending=False)
)

null_percentage.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 null_percentage = (
# ----> 2     df.isnull()
#       3       .mean()
#       4       .mul(100)
#       5       .sort_values(ascending=False)
#
# NameError: name 'df' is not defined

# %%
high_nulls = null_percentage[null_percentage > 50]

medium_nulls = null_percentage[
    (null_percentage > 20)
    & (null_percentage <= 50)
]

low_nulls = null_percentage[
    (null_percentage > 0)
    & (null_percentage <= 20)
]

print("Columnas > 50%:", len(high_nulls))
print("Columnas entre 20%-50%:", len(medium_nulls))
print("Columnas < 20%:", len(low_nulls))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 high_nulls = null_percentage[null_percentage > 50]
#       2
#       3 medium_nulls = null_percentage[
#       4     (null_percentage > 20)
#
# NameError: name 'null_percentage' is not defined

# %% [markdown]
# ## Interpretación
#
# [CONCLUSIONES DE CALIDAD]

# %% [markdown]
# # 8. Detección de Registros Duplicados

# %%
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.duplicated().sum()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Interpretación
#
# [CONCLUSIONES SOBRE DUPLICADOS]

# %% [markdown]
# # 9. Variables de Negocio Relevantes
#
# Se analizan las variables con mayor relevancia para el dominio financiero.

# %%
important_cols = [
    # completar según dataset
]

df[important_cols].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       1 important_cols = [
#       2     # completar según dataset
#       3 ]
#       4
# ----> 5 df[important_cols].head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # 10. Variables Categóricas

# %%
categorical_columns = df.select_dtypes(include=["object"])

categorical_columns.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 categorical_columns = df.select_dtypes(include=["object"])
#       2
#       3 categorical_columns.columns.tolist()
#
# NameError: name 'df' is not defined

# %%
for col in categorical_columns.columns:
    print(f"{col}: {df[col].nunique()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 for col in categorical_columns.columns:
#       2     print(f"{col}: {df[col].nunique()}")
#
# NameError: name 'categorical_columns' is not defined

# %% [markdown]
# ## Interpretación
#
# [CATEGORÍAS Y DIMENSIONES]

# %% [markdown]
# # 11. Relaciones del Dataset
#
# ## Dataset Padre
#
# [PARENT]
#
# ## Dataset Hijo
#
# [CHILD]
#
# ## Cardinalidad
#
# [PATTERN]

# %% [markdown]
# # 12. Conclusiones Técnicas
#
# ## Resumen Ejecutivo
#
# [RESUMEN]
#
# ---
#
# ## Métricas Generales
#
# | Métrica | Valor |
# |----------|---------|
# | Filas | |
# | Columnas | |
# | PK | |
# | FK | |
# | Duplicados | |
#
# ---
#
# ## Calidad de Datos
#
# [RESUMEN]
#
# ---
#
# ## Granularidad
#
# [GRANULARIDAD]
#
# ---
#
# ## Relaciones
#
# [RELACIONES]
#
# ---
#
# ## Rol dentro del Modelo Dimensional
#
# [FACT o DIM]
#
# ---
#
# ## Rol dentro de la Arquitectura Lakehouse
#
# [DATASET]
#
# ↓ Bronze
#
# ↓ Silver
#
# ↓ Intermediate
#
# ↓ Gold
#
# ↓ Diamond
#
# ---
#
# ## Recomendaciones para la siguiente fase
#
# 1. Definir Data Contract.
# 2. Diseñar reglas Silver.
# 3. Diseñar transformaciones Intermediate.
# 4. Definir agregaciones Gold.
# 5. Integrar en Diamond.
