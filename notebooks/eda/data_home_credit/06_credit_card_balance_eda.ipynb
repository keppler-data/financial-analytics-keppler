# %% [markdown]
# # Home Credit Risk Analysis
#
# ## Dataset: credit_card_balance.csv
#
# ### Objetivo
#
# Analizar la estructura, calidad y relaciones del dataset para comprender su papel dentro de la arquitectura Lakehouse y del modelo dimensional.
#
# ---
#
# ### Contexto del negocio
#
#
# El dataset `credit_card_balance.csv` contiene el historial mensual de comportamiento de las tarjetas de crédito asociadas a los clientes de Home Credit.
#
# Cada registro representa el estado financiero de una tarjeta de crédito en un período determinado y almacena información relacionada con saldos, límites de crédito, pagos realizados, montos utilizados y niveles de atraso.
#
# La información registrada permite comprender cómo los clientes utilizan sus líneas de crédito y cómo gestionan sus obligaciones financieras revolving.
#
# A diferencia de los créditos tradicionales con cuotas fijas, las tarjetas de crédito representan productos financieros dinámicos cuyo comportamiento puede variar significativamente entre períodos.
#
# Por esta razón, este dataset constituye una fuente fundamental para evaluar hábitos de consumo, capacidad de pago y exposición al riesgo financiero.
#
# ---
#
# ### Rol dentro de la Arquitectura
#
# El dataset forma parte de la capa histórica de comportamiento financiero y complementa la información proveniente de solicitudes, créditos y pagos.
#
# Su función principal es proporcionar visibilidad sobre la utilización y administración de productos de crédito revolving por parte de los clientes.
#
# application_train
#         │
#         ▼
# previous_application
#         │
#         ▼
# credit_card_balance
#
# La información contenida en esta fuente permitirá construir indicadores relacionados con:
#
# - Utilización de líneas de crédito.
# - Comportamiento revolving.
# - Frecuencia de pago.
# - Exposición financiera.
# - Niveles de atraso.
# - Riesgo asociado al uso de tarjetas de crédito.

# %% [markdown]
# # 1. Importación de librerías
#
# Se cargan las librerías necesarias para el análisis exploratorio de datos.

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)

# %% [markdown]
# # 2. Carga del Dataset
#
# Se carga el dataset para realizar el análisis exploratorio y comprender su estructura, calidad y relevancia dentro del dominio de negocio.

# %%
df = pd.read_csv("../../../data/raw/homeCredit/credit_card_balance.csv")

print(f"Filas: {df.shape[0]}")
print(f"Columnas: {df.shape[1]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("../../../data/raw/homeCredit/credit_card_balance.csv")
#       2
#       3 print(f"Filas: {df.shape[0]}")
#       4 print(f"Columnas: {df.shape[1]}")
#
# ...

# %% [markdown]
# # 3. Tamaño del Dataset
#
# ## Resultados
#
# | Métrica | Valor |
# |----------|---------|
# | Filas | 3,840,312 |
# | Columnas | 23 |
#
# ## Interpretación
#
# El dataset `credit_card_balance.csv` contiene 3,840,312 registros distribuidos en 23 columnas.
#
# El volumen de información evidencia que se trata de una fuente histórica orientada al seguimiento periódico del comportamiento de las tarjetas de crédito asociadas a los clientes.
#
# Cada registro representa el estado financiero de una tarjeta de crédito durante un período específico, permitiendo analizar la evolución temporal de variables relacionadas con saldos, pagos, límites de crédito y niveles de utilización.
#
# ---
#
# ### Características Generales
#
# El dataset almacena información relacionada con:
#
# - Saldos de tarjetas de crédito.
# - Límites de crédito disponibles.
# - Pagos realizados.
# - Montos utilizados.
# - Retiros de efectivo.
# - Comportamiento revolving.
# - Niveles de atraso.
#
# ---
#
# ### Relevancia para el Negocio
#
# La información contenida en este dataset permite comprender cómo los clientes administran sus líneas de crédito a lo largo del tiempo.
#
# A diferencia de los créditos tradicionales, las tarjetas de crédito representan productos financieros dinámicos donde el nivel de endeudamiento puede variar mensualmente.
#
# Por esta razón, el dataset proporciona una visión detallada del comportamiento financiero observado y de la exposición crediticia de cada cliente.
#
# ---
#
# ### Relevancia para el Riesgo Crediticio
#
# El comportamiento de las tarjetas de crédito constituye una de las señales más relevantes para la evaluación del riesgo financiero.
#
# A partir de esta información será posible construir indicadores relacionados con:
#
# - Utilización de líneas de crédito.
# - Endeudamiento promedio.
# - Frecuencia de pago.
# - Comportamiento revolving.
# - Niveles de atraso.
# - Exposición financiera histórica.
#
# ---
#
# ### Consideraciones para Ingeniería de Datos
#
# Con más de 3.8 millones de registros, credit_card_balance constituye una fuente de datos de tamaño considerable dentro del ecosistema Home Credit.
#
# Su naturaleza histórica y periódica la convierte en una candidata ideal para procesos de agregación y generación de indicadores analíticos dentro de las capas Silver, Intermediate y Gold de la arquitectura Lakehouse.

# %% [markdown]
# # 4. Vista Preliminar
#
# Se inspeccionan los primeros registros del dataset con el objetivo de comprender su estructura, contenido y nivel de granularidad.
#
# ## Observaciones Iniciales
#
# La muestra evidencia que cada registro representa el estado mensual de una tarjeta de crédito asociada a un cliente.
#
# El dataset almacena información relacionada con saldos, límites de crédito, pagos realizados, retiros de efectivo, montos utilizados y niveles de atraso.
#
# Su naturaleza periódica permite analizar la evolución financiera de los clientes a lo largo del tiempo.
#
# ---
#
# ## Variables Observadas
#
# | Variable | Descripción |
# |-----------|-------------|
# | SK_ID_PREV | Identificador del crédito o producto financiero asociado |
# | SK_ID_CURR | Identificador del cliente |
# | MONTHS_BALANCE | Mes relativo de observación |
# | AMT_BALANCE | Saldo actual de la tarjeta |
# | AMT_CREDIT_LIMIT_ACTUAL | Límite de crédito disponible |
# | AMT_PAYMENT_CURRENT | Pago realizado en el período |
# | AMT_PAYMENT_TOTAL_CURRENT | Pago total realizado |
# | AMT_TOTAL_RECEIVABLE | Deuda total pendiente |
# | NAME_CONTRACT_STATUS | Estado del contrato |
# | SK_DPD | Días de atraso |
# | SK_DPD_DEF | Días de atraso con definición de mora |
#
# ---
#
# ## Hallazgos Iniciales
#
# La muestra permite identificar múltiples dimensiones relacionadas con el comportamiento financiero de los clientes.
#
# ### Gestión del Crédito
#
# Las variables:
#
# - AMT_BALANCE
# - AMT_CREDIT_LIMIT_ACTUAL
#
# permiten analizar el nivel de utilización de la línea de crédito.
#
# Por ejemplo, algunos registros presentan saldos cercanos al límite disponible, lo que podría indicar una mayor exposición financiera.
#
# ---
#
# ### Comportamiento de Pago
#
# Las variables:
#
# - AMT_PAYMENT_CURRENT
# - AMT_PAYMENT_TOTAL_CURRENT
#
# permiten evaluar la capacidad de pago y el cumplimiento de las obligaciones asociadas a la tarjeta.
#
# ---
#
# ### Endeudamiento
#
# Las variables:
#
# - AMT_RECEIVABLE_PRINCIPAL
# - AMT_RECIVABLE
# - AMT_TOTAL_RECEIVABLE
#
# representan diferentes componentes de la deuda asociada al producto financiero.
#
# Estas variables serán fundamentales para medir niveles de exposición crediticia.
#
# ---
#
# ### Uso de la Tarjeta
#
# Las variables:
#
# - AMT_DRAWINGS_ATM_CURRENT
# - AMT_DRAWINGS_POS_CURRENT
# - AMT_DRAWINGS_CURRENT
#
# permiten identificar cómo se utiliza la línea de crédito.
#
# La información registrada permite diferenciar entre:
#
# - Retiros en cajeros.
# - Compras en puntos de venta.
# - Otros movimientos financieros.
#
# ---
#
# ### Riesgo y Mora
#
# Las variables:
#
# - SK_DPD
# - SK_DPD_DEF
#
# permiten medir niveles de atraso y comportamiento de mora.
#
# Estas variables constituyen señales directas de riesgo crediticio.
#
# ---
#
# ## Primera Hipótesis de Granularidad
#
# A partir de los registros observados se plantea la siguiente hipótesis:
#
# 1 registro = 1 estado mensual de una tarjeta de crédito
#
# Esta hipótesis será validada posteriormente mediante el análisis de claves y cardinalidad.
#
# ---
#
# ## Relación con Otros Datasets
#
# Mientras que previous_application registra solicitudes históricas e installments_payments registra eventos de pago, credit_card_balance almacena la evolución mensual del comportamiento de los productos revolving.
#
# Esta característica convierte al dataset en una fuente estratégica para la construcción de indicadores relacionados con endeudamiento, utilización de crédito y exposición financiera.

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # 5. Estructura General
#
# Se analiza la composición estructural del dataset para comprender los tipos de datos utilizados, evaluar la calidad general del esquema y estimar la complejidad de los procesos analíticos posteriores.
#
# ---
#
# ## Resumen Estructural
#
# | Métrica | Valor |
# |----------|---------|
# | Registros | 3,840,312 |
# | Columnas | 23 |
# | Variables Numéricas | 22 |
# | Variables Categóricas | 1 |
# | Tipos de Datos Distintos | 3 |
#
# ---
#
# ## Distribución de Tipos de Datos
#
# | Tipo de Dato | Cantidad |
# |--------------|----------|
# | float64 | 15 |
# | int64 | 7 |
# | string | 1 |
#
# ---
#
# ## Interpretación
#
# El dataset presenta una estructura predominantemente numérica orientada al seguimiento financiero de productos de crédito revolving.
#
# La mayor parte de las variables corresponden a métricas financieras, montos monetarios, conteos de operaciones y niveles de atraso asociados a las tarjetas de crédito.
#
# Esta composición resulta consistente con la naturaleza operativa del dataset, cuyo objetivo es registrar el comportamiento financiero mensual de los clientes.
#
# ---
#
# ## Componentes Principales
#
# ### Variables Identificadoras
#
# Las columnas:
#
# - SK_ID_PREV
# - SK_ID_CURR
#
# permiten relacionar cada observación con el cliente y el producto financiero correspondiente.
#
# ---
#
# ### Variables Temporales
#
# La columna:
#
# - MONTHS_BALANCE
#
# permite analizar la evolución histórica del comportamiento financiero a lo largo del tiempo.
#
# Cada registro representa una fotografía mensual del estado de la tarjeta de crédito.
#
# ---
#
# ### Variables Financieras
#
# El dataset incorpora múltiples métricas relacionadas con:
#
# - Saldos.
# - Límites de crédito.
# - Pagos realizados.
# - Deudas pendientes.
# - Utilización de crédito.
# - Retiros de efectivo.
#
# Estas variables constituyen la base para el análisis de exposición financiera y riesgo crediticio.
#
# ---
#
# ### Variables Operativas
#
# Las columnas de conteo permiten medir:
#
# - Número de retiros.
# - Número de transacciones.
# - Cantidad de operaciones realizadas.
#
# Estas métricas complementan el análisis del comportamiento financiero de los clientes.
#
# ---
#
# ### Variables de Riesgo
#
# Las variables:
#
# - SK_DPD
# - SK_DPD_DEF
#
# permiten identificar situaciones de atraso y mora.
#
# Estas columnas representan señales directas de riesgo crediticio y serán especialmente relevantes para la construcción de indicadores analíticos.
#
# ---
#
# ### Variable Categórica
#
# El dataset incorpora una única variable categórica:
#
# - NAME_CONTRACT_STATUS
#
# Esta columna describe el estado del contrato asociado a la tarjeta de crédito y permitirá segmentar los registros según la situación operativa del producto financiero.
#
# ---
#
# ## Calidad Estructural
#
# La estructura observada presenta una distribución equilibrada entre variables financieras, operativas y de riesgo.
#
# La predominancia de atributos numéricos favorece los procesos de agregación, análisis estadístico y generación de indicadores históricos.
#
# ---
#
# ## Consideraciones para Ingeniería de Datos
#
# Con más de 3.8 millones de registros y una estructura altamente numérica, credit_card_balance constituye una fuente estratégica para la construcción de métricas históricas relacionadas con endeudamiento, utilización de crédito y comportamiento financiero.
#
# Su naturaleza periódica permitirá generar agregaciones temporales dentro de las capas Silver, Intermediate y Gold de la arquitectura Lakehouse.

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.dtypes.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.dtypes.value_counts()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # 6. Identificación de Claves
#
# Se identifican:
#
# - Clave primaria
# - Claves foráneas
# - Relaciones con otros datasets

# %%
len(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 len(df)
#
# NameError: name 'df' is not defined

# %%
df["SK_ID_PREV"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df["SK_ID_PREV"].nunique()
#
# NameError: name 'df' is not defined

# %%
df["SK_ID_CURR"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df["SK_ID_CURR"].nunique()
#
# NameError: name 'df' is not defined

# %%
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.duplicated().sum()
#
# NameError: name 'df' is not defined

# %%
df[
    ["SK_ID_PREV", "MONTHS_BALANCE"]
].duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df[
#       2     ["SK_ID_PREV", "MONTHS_BALANCE"]
#       3 ].duplicated().sum()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Clave Primaria Candidata
#
# El análisis de cardinalidad permitió identificar una combinación de columnas que garantiza unicidad a nivel de registro:
#
# | Columna |
# |----------|
# | SK_ID_PREV |
# | MONTHS_BALANCE |
#
# Validación realizada:
#
# | Métrica | Valor |
# |----------|---------|
# | Duplicados (SK_ID_PREV + MONTHS_BALANCE) | 0 |
#
# ---
#
# ### Interpretación
#
# La combinación entre SK_ID_PREV y MONTHS_BALANCE identifica de manera única cada observación dentro del dataset.
#
# Esto indica que cada registro representa una fotografía mensual del estado financiero de una tarjeta de crédito o producto revolving.
#
# Por lo tanto, la granularidad observada puede definirse como:
#
# 1 registro = 1 producto financiero en 1 mes específico
#
# ---
#
# ### Claves Foráneas
#
# #### SK_ID_CURR
#
# Permite relacionar cada observación con el cliente correspondiente.
#
# #### SK_ID_PREV
#
# Permite relacionar cada observación con el producto financiero asociado.
#
# ---
#
# ### Cardinalidad
#
# application_train (1)
#
# ↓
#
# credit_card_balance (N)
#
# Un cliente puede registrar múltiples productos financieros y múltiples observaciones mensuales.
#
# ---
#
# ### Relación Temporal
#
# Producto financiero (1)
#
# ↓
#
# Histórico mensual (N)
#
# Cada producto financiero genera múltiples registros a lo largo del tiempo, uno por cada período representado en MONTHS_BALANCE.
#
# ---
#
# ### Conclusión
#
# La combinación SK_ID_PREV + MONTHS_BALANCE constituye una clave de negocio válida para identificar de forma única cada observación dentro del dataset.
#
# Esta estructura confirma que credit_card_balance funciona como una tabla histórica de comportamiento financiero mensual.

# %% [markdown]
# # 7. Calidad de Datos
#
# Se analiza la completitud de la información y posibles problemas de calidad.

# %%
null_percentage = (
    df.isnull()
      .mean()
      .mul(100)
      .sort_values(ascending=False)
)

null_percentage.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 null_percentage = (
# ----> 2     df.isnull()
#       3       .mean()
#       4       .mul(100)
#       5       .sort_values(ascending=False)
#
# NameError: name 'df' is not defined

# %%
high_nulls = null_percentage[null_percentage > 50]

medium_nulls = null_percentage[
    (null_percentage > 20)
    & (null_percentage <= 50)
]

low_nulls = null_percentage[
    (null_percentage > 0)
    & (null_percentage <= 20)
]

print("Columnas > 50%:", len(high_nulls))
print("Columnas entre 20%-50%:", len(medium_nulls))
print("Columnas < 20%:", len(low_nulls))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 high_nulls = null_percentage[null_percentage > 50]
#       2
#       3 medium_nulls = null_percentage[
#       4     (null_percentage > 20)
#
# NameError: name 'null_percentage' is not defined

# %%
null_percentage[null_percentage > 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 null_percentage[null_percentage > 0]
#
# NameError: name 'null_percentage' is not defined

# %% [markdown]
# ## Interpretación
#
# El análisis de calidad de datos evidencia un alto nivel de completitud dentro del dataset.
#
# No se identificaron columnas con niveles críticos de valores faltantes y la mayoría de las variables presentan información prácticamente completa.
#
# ---
#
# ### Distribución de Completitud
#
# | Categoría | Cantidad |
# |------------|----------|
# | Columnas > 50% nulos | 0 |
# | Columnas entre 20% y 50% | 0 |
# | Columnas < 20% | 9 |
#
# ---
#
# ### Interpretación General
#
# Los resultados indican que el dataset mantiene una estructura consistente y adecuada para procesos analíticos y de ingeniería de datos.
#
# La ausencia de columnas con niveles elevados de valores faltantes reduce significativamente los riesgos asociados a pérdidas de información durante las etapas de transformación y agregación.
#
# ---
#
# ### Calidad Observada
#
# La mayoría de las variables financieras, temporales y operativas presentan una cobertura prácticamente completa.
#
# Esto resulta especialmente relevante debido a la naturaleza histórica del dataset, donde la integridad de la información es fundamental para reconstruir el comportamiento financiero de los clientes.
#
# ---
#
# ### Posibles Explicaciones de los Valores Faltantes
#
# Las columnas que presentan valores faltantes corresponden a un porcentaje reducido del total de registros.
#
# En este tipo de datasets, los valores nulos suelen estar asociados a:
#
# - Operaciones que no ocurrieron durante un período específico.
# - Productos financieros sin actividad registrada.
# - Movimientos no aplicables para determinados clientes.
# - Situaciones operativas propias del negocio.
#
# Por lo tanto, los valores faltantes identificados no necesariamente representan problemas de calidad de datos.
#
# ---
#
# ### Implicaciones para la Arquitectura Lakehouse
#
# #### Bronze
#
# Los datos deben conservarse sin modificaciones para mantener la trazabilidad de la información original.
#
# #### Silver
#
# Será necesario validar la naturaleza de los valores faltantes e identificar si corresponden a eventos no aplicables o a información pendiente de registro.
#
# #### Gold
#
# Las variables con valores faltantes deberán considerarse durante la construcción de indicadores financieros para evitar sesgos en los análisis agregados.
#
# ---
#
# ### Conclusión
#
# El dataset credit_card_balance presenta un nivel de calidad elevado y una estructura consistente para el análisis histórico del comportamiento financiero asociado a tarjetas de crédito.
#
# La baja proporción de valores faltantes observada facilita la construcción de métricas relacionadas con utilización de crédito, endeudamiento y riesgo financiero.

# %% [markdown]
# # 8. Detección de Registros Duplicados

# %%
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.duplicated().sum()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Interpretación
#
# Se realizó una validación de duplicidad sobre la totalidad de los registros presentes en el dataset.
#
# ---
#
# ### Resultados
#
# | Métrica | Valor |
# |----------|---------|
# | Registros Totales | 3,840,312 |
# | Registros Duplicados | 0 |
# | Porcentaje de Duplicados | 0% |
#
# ---
#
# ### Hallazgos
#
# No se identificaron registros completamente duplicados dentro del dataset.
#
# Este resultado confirma la consistencia estructural de la información almacenada y garantiza que cada observación mensual representa una entidad única dentro del historial de comportamiento financiero.
#
# ---
#
# ### Interpretación de Negocio
#
# La ausencia de duplicados resulta especialmente relevante debido a la naturaleza histórica y periódica del dataset.
#
# Cada registro representa el estado financiero de una tarjeta de crédito en un período específico y su correcta identificación es fundamental para el análisis de tendencias y evolución temporal.
#
# La inexistencia de duplicados evita distorsiones en indicadores relacionados con:
#
# - Saldos promedio.
# - Utilización de crédito.
# - Niveles de endeudamiento.
# - Frecuencia de pagos.
# - Indicadores de mora.
# - Exposición financiera.
#
# ---
#
# ### Implicaciones para la Arquitectura Lakehouse
#
# #### Bronze
#
# Los registros pueden almacenarse sin necesidad de aplicar procesos de deduplicación.
#
# #### Silver
#
# Los esfuerzos de validación podrán concentrarse en calidad de datos, consistencia temporal y reglas de negocio asociadas al comportamiento financiero.
#
# #### Gold
#
# La ausencia de duplicados garantiza la confiabilidad de los indicadores históricos construidos a partir de la evolución mensual de las tarjetas de crédito.
#
# ---
#
# ### Conclusión
#
# El dataset presenta una estructura consistente y libre de registros duplicados, fortaleciendo su confiabilidad como fuente principal para el análisis de comportamiento financiero revolving.

# %% [markdown]
# # 9. Variables de Negocio Relevantes
#
# Se analizan las variables con mayor relevancia para el dominio financiero.

# %%
important_cols = [
    "SK_ID_PREV",
    "SK_ID_CURR",
    "MONTHS_BALANCE",
    "AMT_BALANCE",
    "AMT_CREDIT_LIMIT_ACTUAL",
    "AMT_PAYMENT_CURRENT",
    "AMT_TOTAL_RECEIVABLE",
    "SK_DPD"
]

df[important_cols].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 12
#       8     "AMT_TOTAL_RECEIVABLE",
#       9     "SK_DPD"
#      10 ]
#      11
# ---> 12 df[important_cols].head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Interpretación
#
# Las variables seleccionadas representan los principales indicadores asociados al comportamiento financiero de las tarjetas de crédito dentro del ecosistema Home Credit.
#
# A diferencia de otros datasets enfocados en solicitudes o pagos de cuotas, credit_card_balance permite observar la evolución mensual de la deuda, los pagos realizados y la utilización de las líneas de crédito.
#
# ---
#
# ### Variables Identificadas
#
# | Variable | Descripción |
# |-----------|-------------|
# | SK_ID_PREV | Identificador del producto financiero asociado |
# | SK_ID_CURR | Identificador del cliente |
# | MONTHS_BALANCE | Mes relativo de observación |
# | AMT_BALANCE | Saldo actual de la tarjeta |
# | AMT_CREDIT_LIMIT_ACTUAL | Límite de crédito disponible |
# | AMT_PAYMENT_CURRENT | Pago realizado durante el período |
# | AMT_TOTAL_RECEIVABLE | Deuda total pendiente |
# | SK_DPD | Días de atraso |
#
# ---
#
# ### Relevancia de Negocio
#
# #### SK_ID_PREV
#
# Permite identificar el producto financiero asociado a cada observación mensual.
#
# Será utilizado para reconstruir la evolución histórica de cada tarjeta de crédito.
#
# ---
#
# #### SK_ID_CURR
#
# Permite asociar el comportamiento financiero observado al cliente correspondiente.
#
# Esta variable será utilizada posteriormente para generar métricas agregadas de riesgo y exposición financiera.
#
# ---
#
# #### MONTHS_BALANCE
#
# Representa el período temporal de observación.
#
# Permite analizar tendencias históricas y evolución del comportamiento financiero de los clientes.
#
# ---
#
# #### AMT_BALANCE
#
# Corresponde al saldo actual registrado en la tarjeta de crédito.
#
# Esta variable permite medir niveles de endeudamiento y utilización de crédito.
#
# ---
#
# #### AMT_CREDIT_LIMIT_ACTUAL
#
# Representa el límite de crédito disponible para el cliente.
#
# Su comparación con el saldo permite evaluar niveles de exposición financiera.
#
# ---
#
# #### AMT_PAYMENT_CURRENT
#
# Corresponde al pago realizado durante el período analizado.
#
# Permite evaluar capacidad de pago y comportamiento financiero.
#
# ---
#
# #### AMT_TOTAL_RECEIVABLE
#
# Representa la deuda total pendiente asociada al producto financiero.
#
# Constituye una de las principales variables para medir riesgo y exposición crediticia.
#
# ---
#
# #### SK_DPD
#
# Representa los días de atraso registrados durante el período.
#
# Esta variable constituye una señal directa de incumplimiento financiero y riesgo crediticio.
#
# ---
#
# ### Hallazgos Iniciales
#
# La muestra evidencia que los clientes presentan diferentes niveles de utilización de crédito y endeudamiento.
#
# Asimismo, se observan diferencias importantes entre:
#
# - Saldo utilizado.
# - Límite de crédito disponible.
# - Pagos realizados.
# - Deuda pendiente.
#
# Estas diferencias reflejan distintos comportamientos financieros y niveles de exposición al riesgo.
#
# ---
#
# ### Indicadores Potenciales
#
# A partir de estas variables será posible construir métricas relacionadas con:
#
# - Utilización de crédito.
# - Endeudamiento promedio.
# - Exposición financiera.
# - Capacidad de pago.
# - Historial de mora.
# - Frecuencia de atraso.
# - Riesgo asociado a tarjetas de crédito.
#
# ---
#
# ### Conclusión
#
# Las variables analizadas constituyen la base para comprender el comportamiento financiero revolving de los clientes.
#
# Su combinación permitirá generar indicadores de alto valor para procesos analíticos, modelos predictivos y evaluación de riesgo crediticio dentro de las futuras capas Silver, Intermediate, Gold y Diamond de la arquitectura Lakehouse.

# %% [markdown]
# # 10. Variables Categóricas

# %%
categorical_columns = df.select_dtypes(include=["object"])

categorical_columns.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 categorical_columns = df.select_dtypes(include=["object"])
#       2
#       3 categorical_columns.columns.tolist()
#
# NameError: name 'df' is not defined

# %%
df["NAME_CONTRACT_STATUS"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df["NAME_CONTRACT_STATUS"].nunique()
#
# NameError: name 'df' is not defined

# %%
df["NAME_CONTRACT_STATUS"].value_counts(normalize=True).mul(100).round(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df["NAME_CONTRACT_STATUS"].value_counts(normalize=True).mul(100).round(2)
#
# NameError: name 'df' is not defined

# %%
for col in categorical_columns.columns:
    print(f"{col}: {df[col].nunique()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 for col in categorical_columns.columns:
#       2     print(f"{col}: {df[col].nunique()}")
#
# NameError: name 'categorical_columns' is not defined

# %% [markdown]
# ## Interpretación
#
# Se realizó la identificación de variables categóricas presentes en el dataset con el objetivo de comprender los estados operativos asociados a los productos de crédito revolving.
#
# ---
#
# ### Variables Categóricas Identificadas
#
# | Variable | Categorías |
# |-----------|-----------|
# | NAME_CONTRACT_STATUS | 7 |
#
# ---
#
# ### Distribución de Estados del Contrato
#
# | Estado | Participación |
# |----------|-------------|
# | Active | 96.31% |
# | Completed | 3.36% |
# | Signed | 0.29% |
# | Demand | 0.04% |
# | Sent proposal | 0.01% |
# | Refused | 0.00% |
# | Approved | 0.00% |
#
# ---
#
# ### Interpretación General
#
# La distribución observada evidencia que la gran mayoría de los registros corresponden a contratos activos.
#
# Esto resulta consistente con la naturaleza histórica del dataset, ya que cada observación representa una fotografía mensual del comportamiento financiero de productos de crédito que se encuentran en operación.
#
# ---
#
# ### Hallazgos Relevantes
#
# #### Contratos Activos
#
# Los contratos con estado **Active** representan el 96.31% de los registros.
#
# Este resultado indica que la mayor parte de las observaciones corresponden a productos financieros que permanecían vigentes durante el período analizado.
#
# ---
#
# #### Contratos Completados
#
# Los contratos **Completed** representan el 3.36% del total.
#
# Estos registros corresponden a productos financieros que finalizaron su ciclo operativo.
#
# ---
#
# #### Estados Minoritarios
#
# Los estados:
#
# - Signed
# - Demand
# - Sent proposal
# - Refused
# - Approved
#
# presentan una participación marginal dentro del dataset.
#
# Sin embargo, estos estados pueden aportar información valiosa para procesos de segmentación y análisis de comportamiento financiero.
#
# ---
#
# ### Valor Analítico
#
# La variable NAME_CONTRACT_STATUS permitirá segmentar los registros según el estado operativo de los productos financieros.
#
# Esta información podrá utilizarse para:
#
# - Analizar diferencias de comportamiento entre contratos activos y finalizados.
# - Construir métricas de riesgo segmentadas.
# - Identificar patrones asociados a distintos estados contractuales.
#
# ---
#
# ### Conclusión
#
# Aunque el dataset incorpora una única variable categórica, su relevancia analítica es significativa debido a que describe el estado operativo de los productos financieros observados.
#
# La alta concentración de contratos activos confirma que credit_card_balance constituye principalmente una fuente orientada al seguimiento de productos financieros vigentes y su comportamiento a lo largo del tiempo.

# %% [markdown]
# ## Interpretación
#
# El dataset `credit_card_balance.csv` almacena el comportamiento histórico mensual asociado a productos de crédito revolving utilizados por los clientes de Home Credit.
#
# Su función principal es proporcionar visibilidad sobre la evolución financiera de las tarjetas de crédito a lo largo del tiempo.
#
# ---
#
# ### Relación Principal
#
# El dataset se relaciona con las demás fuentes mediante dos identificadores clave:
#
# | Variable | Relación |
# |-----------|----------|
# | SK_ID_CURR | Cliente |
# | SK_ID_PREV | Producto financiero |
#
# ---
#
# ### Relación con application_train
#
# application_train (1)
#
# ↓
#
# credit_card_balance (N)
#
# Un cliente puede registrar múltiples observaciones históricas asociadas a tarjetas de crédito.
#
# ---
#
# ### Relación con previous_application
#
# previous_application (1)
#
# ↓
#
# credit_card_balance (N)
#
# Un producto financiero puede generar múltiples observaciones mensuales durante su ciclo de vida.
#
# ---
#
# ### Jerarquía de Información
#
# Cliente
#
# ↓
#
# Solicitud Actual
#
# ↓
#
# Producto Financiero
#
# ↓
#
# Histórico Mensual de Tarjeta de Crédito
#
# Esta estructura permite reconstruir la evolución temporal del comportamiento financiero de los clientes.
#
# ---
#
# ### Granularidad
#
# 1 registro = 1 producto financiero en 1 período mensual
#
# La combinación:
#
# - SK_ID_PREV
# - MONTHS_BALANCE
#
# permite identificar de forma única cada observación dentro del dataset.
#
# ---
#
# ### Integración con el Modelo Dimensional
#
# El dataset constituye una de las principales fuentes para la construcción de indicadores relacionados con:
#
# - Utilización de crédito.
# - Endeudamiento.
# - Exposición financiera.
# - Comportamiento revolving.
# - Historial de mora.
# - Capacidad de pago.
#
# ---
#
# ### Relevancia para la Arquitectura Lakehouse
#
# Durante las etapas Silver e Intermediate, este dataset permitirá consolidar métricas históricas asociadas al uso de tarjetas de crédito.
#
# Posteriormente, dichas métricas enriquecerán las capas Gold y Diamond mediante atributos relacionados con comportamiento financiero y riesgo crediticio.
#
# ---
#
# ### Conclusión
#
# credit_card_balance representa una fuente estratégica para comprender la evolución mensual de los productos revolving utilizados por los clientes.
#
# Su integración con application_train y previous_application permitirá construir una visión más completa del comportamiento financiero observado.

# %% [markdown]
# # 12. Conclusiones Técnicas
#
# ## Resumen Ejecutivo
#
# El dataset `credit_card_balance.csv` almacena el historial mensual de comportamiento asociado a productos de crédito revolving utilizados por los clientes de Home Credit.
#
# Su principal objetivo es registrar la evolución de saldos, pagos, utilización de crédito y niveles de atraso observados a lo largo del tiempo.
#
# Esta fuente proporciona una visión detallada del comportamiento financiero de los clientes y constituye uno de los principales insumos para la construcción de indicadores de riesgo crediticio.
#
# ---
#
# ## Métricas Generales
#
# | Métrica | Valor |
# |----------|---------|
# | Registros | 3,840,312 |
# | Columnas | 23 |
# | Variables Numéricas | 22 |
# | Variables Categóricas | 1 |
# | Duplicados | 0 |
#
# ---
#
# ## Calidad de Datos
#
# El dataset presenta un nivel elevado de calidad y consistencia estructural.
#
# Las validaciones realizadas evidenciaron:
#
# - Ausencia de registros duplicados.
# - Ausencia de columnas con niveles críticos de valores faltantes.
# - Integridad adecuada en variables financieras y operativas.
#
# La mayoría de las columnas presentan una cobertura prácticamente completa, lo que favorece la construcción de indicadores analíticos robustos.
#
# ---
#
# ## Granularidad
#
# Cada registro representa:
#
# **1 producto financiero en 1 período mensual específico**
#
# La combinación:
#
# - SK_ID_PREV
# - MONTHS_BALANCE
#
# garantiza la unicidad de las observaciones dentro del dataset.
#
# ---
#
# ## Relaciones Identificadas
#
# ### Relación con application_train
#
# application_train (1)
#
# ↓
#
# credit_card_balance (N)
#
# ---
#
# ### Relación con previous_application
#
# previous_application (1)
#
# ↓
#
# credit_card_balance (N)
#
# Estas relaciones permiten reconstruir la evolución financiera histórica de los clientes.
#
# ---
#
# ## Variables de Negocio Relevantes
#
# Las variables de mayor valor analítico identificadas fueron:
#
# - AMT_BALANCE
# - AMT_CREDIT_LIMIT_ACTUAL
# - AMT_PAYMENT_CURRENT
# - AMT_TOTAL_RECEIVABLE
# - SK_DPD
# - MONTHS_BALANCE
#
# Estas variables permiten caracterizar la utilización del crédito, el nivel de endeudamiento y el comportamiento financiero observado.
#
# ---
#
# ## Hallazgos Principales
#
# ### Estado de los Contratos
#
# | Estado | Participación |
# |----------|-------------|
# | Active | 96.31% |
# | Completed | 3.36% |
# | Otros estados | < 1% |
#
# La gran mayoría de los registros corresponden a contratos activos, lo que confirma que el dataset se encuentra orientado principalmente al seguimiento de productos financieros vigentes.
#
# ---
#
# ### Estructura Financiera
#
# El dataset incorpora información relacionada con:
#
# - Saldos.
# - Límites de crédito.
# - Pagos realizados.
# - Deuda pendiente.
# - Movimientos financieros.
# - Niveles de atraso.
#
# Esta combinación permite construir una visión integral del comportamiento revolving de los clientes.
#
# ---
#
# ### Valor Analítico
#
# La información contenida en credit_card_balance permite analizar:
#
# - Utilización de líneas de crédito.
# - Exposición financiera.
# - Endeudamiento histórico.
# - Frecuencia de pagos.
# - Comportamiento de mora.
# - Gestión de deuda revolving.
#
# Estas características convierten al dataset en una fuente estratégica para procesos de análisis de riesgo.
#
# ---
#
# ## Rol dentro del Modelo Dimensional
#
# El dataset es candidato natural para la construcción de una tabla de hechos asociada al comportamiento de tarjetas de crédito.
#
# ### FACT_CREDIT_CARD_BALANCE
#
# A partir de esta información podrán construirse indicadores como:
#
# - Utilización promedio de crédito.
# - Saldo promedio.
# - Exposición financiera máxima.
# - Frecuencia de atraso.
# - Nivel promedio de endeudamiento.
# - Historial de comportamiento revolving.
#
# ---
#
# ## Rol dentro de la Arquitectura Lakehouse
#
# credit_card_balance.csv
#
# ↓
#
# Bronze (ingesta cruda)
#
# ↓
#
# Silver (validación y normalización)
#
# ↓
#
# Intermediate (agregaciones históricas)
#
# ↓
#
# Gold (indicadores de comportamiento financiero)
#
# ↓
#
# Diamond (convergencia corporativa)
#
# ---
#
# ## Recomendaciones para la Siguiente Fase
#
# 1. Integrar credit_card_balance con previous_application mediante SK_ID_PREV.
# 2. Consolidar métricas históricas por cliente utilizando SK_ID_CURR.
# 3. Construir indicadores de utilización de crédito y exposición financiera.
# 4. Incorporar métricas de mora y atraso dentro de las capas Gold y Diamond.
# 5. Diseñar agregaciones temporales que permitan analizar tendencias de comportamiento financiero.
#
# ---
#
# ## Conclusión Final
#
# credit_card_balance constituye una de las principales fuentes para comprender el comportamiento financiero revolving de los clientes de Home Credit.
#
# Su estructura histórica, calidad de datos y riqueza de variables financieras permiten construir indicadores robustos de utilización de crédito, endeudamiento y riesgo financiero, convirtiéndolo en un componente fundamental dentro de la arquitectura analítica del proyecto.
